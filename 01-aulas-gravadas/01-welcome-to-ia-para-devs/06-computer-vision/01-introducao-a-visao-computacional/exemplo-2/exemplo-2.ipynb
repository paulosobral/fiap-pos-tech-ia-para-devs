# %%
import cv2
import matplotlib.pyplot as plt

# Carregar a imagem
imagem = cv2.imread('face.jpeg')

# Converter de BGR para RGB
# imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
# plt.imshow(imagem_rgb)

# Converter de BGR para escala de cinza
# imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
# plt.imshow(imagem_rgb, cmap='gray')

# Aplicar Suavização Gaussiana
# imagem_suavilizada = cv2.GaussianBlur(imagem, (15, 15), 0)
# imagem_suavizada_rgb = cv2.cvtColor(imagem_suavilizada, cv2.COLOR_BGR2RGB)
# plt.imshow(imagem_suavizada_rgb)

# Exibir a imagem com detecção de bordas Canny
# imagem_gray = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
# bordas = cv2.Canny(imagem_gray, 100, 200)
# plt.imshow(bordas, cmap='gray')

# Definir as coordenadas e a cor do retângulo
inicio = (750, 50) # canto superior esquerdo
fim = (2000, 1400) # canto inferior direito
cor = (255, 0, 0)  # Azul em BGR
espessura = 8

# Desenhar o retângulo na cópia da imagem e a salva
imagem_com_retangulo = cv2.rectangle(imagem.copy(), inicio, fim, cor, espessura)
imagem_com_retangulo_rgb = cv2.cvtColor(imagem_com_retangulo, cv2.COLOR_BGR2RGB)
plt.imshow(imagem_com_retangulo_rgb)
caminho_salvar = 'imagem_processada.jpeg'
cv2.imwrite(caminho_salvar, imagem_com_retangulo)

# Desativar os eixos
plt.axis('off')
plt.show()
