# %%
#!pip install openai

# %%
from openai import OpenAI
client = OpenAI(api_key=os.environ.get('OPENAI_API_KEY'))

# %%
from dotenv import load_dotenv

load_dotenv()
import os

# %%
# Nota: dall-e-2 e dall-e-3 foram descontinuados em 12/05/2026
# Use gpt-image-1 ou gpt-image-1-mini em vez disso
response = client.images.generate(
  model="gpt-image-1",  # ou "gpt-image-1-mini"
  prompt="a student learning about AI",
  size="1024x1024",
  quality="high",  # valores: low, medium, high, auto
  n=1,
  output_format="png"  # png ou jpeg
)

# A resposta agora retorna base64 em vez de URL
import base64
image_data = response.data[0].b64_json
image_bytes = base64.b64decode(image_data)

# Salvar a imagem em um arquivo
with open('student_learning_ai.png', 'wb') as f:
    f.write(image_bytes)

print("Imagem salva como 'student_learning_ai.png'")
# Out:
# Imagem salva como 'student_learning_ai.png'

# %%
# A imagem foi salva como 'student_learning_ai.png'

# %% [markdown]
# Níveis diferentes de prompt

# %%
# Nota: dall-e-2 e dall-e-3 foram descontinuados em 12/05/2026
# Use gpt-image-1 ou gpt-image-1-mini em vez disso

# Prompt Simples
response_simples = client.images.generate(
  model="gpt-image-1",
  prompt="Um desenho simples de uma cidade futurista com temática cyberpunk.",
  size="1024x1024",
  quality="high",
  n=1,
  output_format="png"
)

import base64
image_data_simples = response_simples.data[0].b64_json
image_bytes_simples = base64.b64decode(image_data_simples)
with open('cidade_simples.png', 'wb') as f:
    f.write(image_bytes_simples)
print("Imagem Simples salva como 'cidade_simples.png'")

# Prompt Intermediário
response_intermediario = client.images.generate(
  model="gpt-image-1",
  prompt="Uma paisagem urbana futurista com luzes neon e arranha-céus imponentes, apresentando carros voadores e elementos cyberpunk.",
  size="1024x1024",
  quality="high",
  n=1,
  output_format="png"
)

image_data_intermediario = response_intermediario.data[0].b64_json
image_bytes_intermediario = base64.b64decode(image_data_intermediario)
with open('cidade_intermediaria.png', 'wb') as f:
    f.write(image_bytes_intermediario)
print("Imagem Intermediária salva como 'cidade_intermediaria.png'")

# Prompt Avançado
response_avancado = client.images.generate(
  model="gpt-image-1",
  prompt="Uma cidade futurista extensa com temática cyberpunk, cheia de arranha-céus adornados com placas de neon, carros voadores atravessando o ar, ruas movimentadas com pessoas usando roupas de alta tecnologia, e anúncios holográficos iluminando o céu noturno.",
  size="1024x1024",
  quality="high",
  n=1,
  output_format="png"
)

image_data_avancado = response_avancado.data[0].b64_json
image_bytes_avancado = base64.b64decode(image_data_avancado)
with open('cidade_avancada.png', 'wb') as f:
    f.write(image_bytes_avancado)
print("Imagem Avançada salva como 'cidade_avancada.png'")
# Out:
# Imagem Simples salva como 'cidade_simples.png'
# Imagem Intermediária salva como 'cidade_intermediaria.png'
# Imagem Avançada salva como 'cidade_avancada.png'

# %% [markdown]
# ###Em ingles

# %%
# Nota: dall-e-2 e dall-e-3 foram descontinuados em 12/05/2026
# Use gpt-image-1 ou gpt-image-1-mini em vez disso

# Prompt Simples
response_simple = client.images.generate(
  model="gpt-image-1",
  prompt="A simple drawing of a futuristic city with a cyberpunk theme.",
  size="1024x1024",
  quality="high",
  n=1,
  output_format="png"
)

import base64
image_data_simple = response_simple.data[0].b64_json
image_bytes_simple = base64.b64decode(image_data_simple)
with open('city_simple.png', 'wb') as f:
    f.write(image_bytes_simple)
print("Simple Image saved as 'city_simple.png'")

# Prompt Intermediário
response_intermediate = client.images.generate(
  model="gpt-image-1",
  prompt="A futuristic cityscape with neon lights and towering skyscrapers, featuring flying cars and cyberpunk elements.",
  size="1024x1024",
  quality="high",
  n=1,
  output_format="png"
)

image_data_intermediate = response_intermediate.data[0].b64_json
image_bytes_intermediate = base64.b64decode(image_data_intermediate)
with open('city_intermediate.png', 'wb') as f:
    f.write(image_bytes_intermediate)
print("Intermediate Image saved as 'city_intermediate.png'")

# Prompt Avançado
response_advanced = client.images.generate(
  model="gpt-image-1",
  prompt="A sprawling futuristic city with a cyberpunk theme, filled with towering skyscrapers adorned with neon signs, flying cars zipping through the air, bustling streets with people in high-tech attire, and holographic advertisements lighting up the night sky.",
  size="1024x1024",
  quality="high",
  n=1,
  output_format="png"
)

image_data_advanced = response_advanced.data[0].b64_json
image_bytes_advanced = base64.b64decode(image_data_advanced)
with open('city_advanced.png', 'wb') as f:
    f.write(image_bytes_advanced)
print("Advanced Image saved as 'city_advanced.png'")

# %% [markdown]
# ###Variações

# %%
# Nota: A função de variações também mudou com a descontinuação do DALL-E
# Verifique a documentação atualizada da OpenAI para o método equivalente com gpt-image-1
# A API de variações pode não estar disponível da mesma forma nos novos modelos
