# %% [markdown]
# # Aula 2 – Vídeo 1: Configuração do Ambiente
# Passos:
# 1. Criar/ativar ambiente e instalar pacotes.
# 2. Configurar `.env` com a chave da OpenAI.
# 3. Validar a chamada a LLM usando `langchain-openai`.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
try:
    from langchain_openai import ChatOpenAI
except Exception:
    ChatOpenAI = None

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
model = os.getenv("OPENAI_MODEL", "gpt-4o-mini")

if ChatOpenAI is None:
    print("[AVISO] 'langchain-openai' não está instalado.")
elif not api_key:
    print("[AVISO] OPENAI_API_KEY não encontrada no .env.")
else:
    llm = ChatOpenAI(model=model, temperature=0.2, max_tokens=64)
    resp = llm.invoke("Diga 'Ambiente OK' em uma frase curta.")
    print("[LLM]", resp.content)
# Out:
# [LLM] Ambiente OK.
